# %%
info ="""My name is Aditya Mali, and I am currently pursuing a Bachelor of Technology (B.Tech) in Computer Science and Engineering at the National Institute of Technology (NIT) Jalandhar. I am a passionate and dedicated student with a strong interest in software development, artificial intelligence, machine learning, data science, and problem-solving. I believe that technology has the power to solve real-world challenges, and this motivates me to continuously learn, explore, and improve my technical skills.
Throughout my academic journey, I have built a solid foundation in programming, data structures and algorithms, object-oriented programming, database management systems, operating systems, and software engineering. I am proficient in programming languages such as C++, Python, Java, and SQL, and I have also worked with tools and technologies including Git, GitHub, Flutter, Jupyter Notebook, and Google Colab. Along with academics, I enjoy building practical projects that help me apply theoretical concepts to real-life situations. These projects have strengthened my understanding of software development, teamwork, debugging, and project management.
I am highly interested in competitive programming and continuously work on improving my coding and analytical skills by solving problems on various online coding platforms. I also enjoy exploring new technologies, participating in hackathons, and learning about the latest advancements in AI and software development. I believe that continuous learning and consistency are the keys to becoming a successful software engineer.
Apart from technical skills, I possess strong communication, teamwork, leadership, and time management abilities. I enjoy collaborating with others, sharing ideas, and working in team environments where I can both contribute and learn. I am a quick learner who adapts easily to new technologies and challenges, and I always strive to maintain a positive attitude while solving problems.
My short-term goal is to secure a software engineering internship where I can gain industry experience, enhance my technical expertise, and contribute meaningfully to impactful projects. In the long term, I aspire to become a skilled Software Development Engineer (SDE) at a leading technology company, where I can develop innovative products, solve complex engineering problems, and continue growing as a technology professional. I am committed to lifelong learning and always look forward to opportunities that challenge me to improve both personally and professionally."""

# %%
import tensorflow as tk
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
token=Tokenizer()

token.fit_on_texts([info])

# %%
token.word_index
# Out:
# {'and': 1,
#  'i': 2,
#  'to': 3,
#  'a': 4,
#  'in': 5,
#  'my': 6,
#  'software': 7,
#  'am': 8,
#  'technology': 9,
#  'the': 10,
#  'engineering': 11,
#  'with': 12,
#  'development': 13,
#  'learning': 14,
#  'that': 15,
#  'programming': 16,
#  'of': 17,
#  'solving': 18,
#  'me': 19,
#  'technical': 20,
#  'skills': 21,
#  'have': 22,
#  'management': 23,
#  'technologies': 24,
#  'enjoy': 25,
#  'projects': 26,
#  'problems': 27,
#  'where': 28,
#  'can': 29,
#  'is': 30,
#  'science': 31,
#  'at': 32,
#  'strong': 33,
#  'data': 34,
#  'believe': 35,
#  'solve': 36,
#  'real': 37,
#  'challenges': 38,
#  'continuously': 39,
#  'learn': 40,
#  'improve': 41,
#  'systems': 42,
#  'as': 43,
#  'also': 44,
#  'teamwork': 45,
#  'on': 46,
#  'coding': 47,
#  'new': 48,
#  'engineer': 49,
#  'both': 50,
#  'contribute': 51,
#  'always': 52,
#  'term': 53,
#  'name': 54,
#  'aditya': 55,
#  'mali': 56,
#  'currently': 57,
#  'pursuing': 58,
#  'bachelor': 59,
#  'b': 60,
# ...

# %%
s=[]
for sentence in info.split('\n'):
    if(len(sentence)==0):
        pass
    print(sentence)
    tokenized_sentence=token.texts_to_sequences([sentence])[0]
    print(tokenized_sentence)
    for i in range(1,len(tokenized_sentence)):
        s.append(tokenized_sentence[:i+1])
# Out:
# My name is Aditya Mali, and I am currently pursuing a Bachelor of Technology (B.Tech) in Computer Science and Engineering at the National Institute of Technology (NIT) Jalandhar. I am a passionate and dedicated student with a strong interest in software development, artificial intelligence, machine learning, data science, and problem-solving. I believe that technology has the power to solve real-world challenges, and this motivates me to continuously learn, explore, and improve my technical skills.
# [6, 54, 30, 55, 56, 1, 2, 8, 57, 58, 4, 59, 17, 9, 60, 61, 5, 62, 31, 1, 11, 32, 10, 63, 64, 17, 9, 65, 66, 2, 8, 4, 67, 1, 68, 69, 12, 4, 33, 70, 5, 7, 13, 71, 72, 73, 14, 34, 31, 1, 74, 18, 2, 35, 15, 9, 75, 10, 76, 3, 36, 37, 77, 38, 1, 78, 79, 19, 3, 39, 40, 80, 1, 41, 6, 20, 21]
# ...

# %%
s
# Out:
# [[6, 54],
#  [6, 54, 30],
#  [6, 54, 30, 55],
#  [6, 54, 30, 55, 56],
#  [6, 54, 30, 55, 56, 1],
#  [6, 54, 30, 55, 56, 1, 2],
#  [6, 54, 30, 55, 56, 1, 2, 8],
#  [6, 54, 30, 55, 56, 1, 2, 8, 57],
#  [6, 54, 30, 55, 56, 1, 2, 8, 57, 58],
#  [6, 54, 30, 55, 56, 1, 2, 8, 57, 58, 4],
#  [6, 54, 30, 55, 56, 1, 2, 8, 57, 58, 4, 59],
#  [6, 54, 30, 55, 56, 1, 2, 8, 57, 58, 4, 59, 17],
#  [6, 54, 30, 55, 56, 1, 2, 8, 57, 58, 4, 59, 17, 9],
#  [6, 54, 30, 55, 56, 1, 2, 8, 57, 58, 4, 59, 17, 9, 60],
#  [6, 54, 30, 55, 56, 1, 2, 8, 57, 58, 4, 59, 17, 9, 60, 61],
#  [6, 54, 30, 55, 56, 1, 2, 8, 57, 58, 4, 59, 17, 9, 60, 61, 5],
#  [6, 54, 30, 55, 56, 1, 2, 8, 57, 58, 4, 59, 17, 9, 60, 61, 5, 62],
#  [6, 54, 30, 55, 56, 1, 2, 8, 57, 58, 4, 59, 17, 9, 60, 61, 5, 62, 31],
#  [6, 54, 30, 55, 56, 1, 2, 8, 57, 58, 4, 59, 17, 9, 60, 61, 5, 62, 31, 1],
#  [6, 54, 30, 55, 56, 1, 2, 8, 57, 58, 4, 59, 17, 9, 60, 61, 5, 62, 31, 1, 11],
#  [6,
#   54,
#   30,
#   55,
#   56,
#   1,
#   2,
#   8,
#   57,
# ...

# %%
from keras.preprocessing.sequence import pad_sequences

input_seq=pad_sequences(s,padding='pre',maxlen=90)

# %%
X=input_seq[: , :-1]
y=input_seq[:,-1]

# %%
from tensorflow.keras.utils import to_categorical

y=to_categorical(y,num_classes=205)

# %%
from keras.models import Sequential
from keras.layers import Embedding,LSTM,Dense

model=Sequential()

model.add(Embedding(input_dim=205,output_dim=100,input_length=89))
model.add(LSTM(150))
model.add(Dense(205,activation='softmax'))
model.build(input_shape=(None,90))
# Out:
# c:\Users\malia\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\embedding.py:103: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_6 (Embedding)         │ (None, 90, 100)        │        20,500 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_6 (LSTM)                   │ (None, 150)            │       150,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 205)            │        30,955 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 202,055 (789.28 KB)
#  Trainable params: 202,055 (789.28 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.fit(X,y,epochs=100)
# Out:
# Epoch 1/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.0466 - loss: 5.3193
# Epoch 2/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.0740 - loss: 5.1221
# Epoch 3/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.0740 - loss: 4.9983
# Epoch 4/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.0740 - loss: 4.9404
# Epoch 5/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.0740 - loss: 4.9014
# Epoch 6/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.0740 - loss: 4.8752
# Epoch 7/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.0740 - loss: 4.8490
# Epoch 8/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.0795 - loss: 4.8121
# Epoch 9/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.0795 - loss: 4.7609
# Epoch 10/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.0849 - loss: 4.6903
# Epoch 11/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.0959 - loss: 4.5995
# ...

# %%
import time
import numpy as np
text = "i have built a solid foudation"

for i in range(10):
  # tokenize
  token_text = token.texts_to_sequences([text])[0]
  # padding
  padded_token_text = pad_sequences([token_text], maxlen=56, padding='pre')
  # predict
  pos = np.argmax(model.predict(padded_token_text))

  for word,index in token.word_index.items():
    if index == pos:
      text = text + " " + word
      print(text)
      time.sleep(2)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# i have built a solid foudation foundation
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# i have built a solid foudation foundation in
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# i have built a solid foudation foundation in programming
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# i have built a solid foudation foundation in programming data
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# i have built a solid foudation foundation in programming data structures
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# i have built a solid foudation foundation in programming data structures and
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# i have built a solid foudation foundation in programming data structures and algorithms
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# i have built a solid foudation foundation in programming data structures and algorithms object
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# ...
